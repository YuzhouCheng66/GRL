# %% [markdown]
# # Tutorial 06: Networks from OpenStreetMap
#
# In this tutorial, we discuss how networks that have been imported from OpenStreetMap can be integrated and run in Flow. This will all be presented via the Bay Bridge network, seen in the figure below. Networks from OpenStreetMap are commonly used in many traffic simulators for the purposes of replicating traffic in realistic traffic geometries. This is true in both SUMO and Aimsun (which are both supported in Flow), with each supporting several techniques for importing such network files. This process is further simplified and abstracted in Flow, with users simply required to specify the path to the osm file in order to simulate traffic in the network.
#
#
# <img src="img/bay_bridge_osm.png" width=750>
# <center> **Figure 1**: Snapshot of the Bay Bridge from OpenStreetMap </center>
#
# Before we begin, let us import all relevant Flow parameters as we have done for previous tutorials. If you are unfamiliar with these parameters, you are encouraged to review tutorial 1.

# %%
# the TestEnv environment is used to simply simulate the network
from flow.envs import TestEnv

# the Experiment class is used for running simulations
from flow.core.experiment import Experiment

# all other imports are standard
from flow.core.params import VehicleParams
from flow.core.params import NetParams
from flow.core.params import InitialConfig
from flow.core.params import EnvParams
from flow.core.params import SumoParams

# %% [markdown]
# ## 1. Running a Default Simulation
#
# In order to create a network object in Flow with network features depicted from OpenStreetMap, we will use the base `Network` class. This class can sufficiently support the generation of any .osm file.

# %%
from flow.networks import Network

# %% [markdown]
# In order to recreate the network features of a specific osm file, the path to the osm file must be specified in `NetParams`. For this example, we will use an osm file extracted from the section of the Bay Bridge as depicted in Figure 1.
#
# In order to specify the path to the osm file, simply fill in the `osm_path` attribute with the path to the .osm file as follows:

# %%
net_params = NetParams(
    osm_path='networks/bay_bridge.osm'
)

# %% [markdown]
# Next, we create all other parameters as we have in tutorials 1 and 2. For this example, we will assume a total of 1000 are uniformly spread across the Bay Bridge. Once again, if the choice of parameters is unclear, you are encouraged to review Tutorial 1.

# %%
# create the remainding parameters
env_params = EnvParams()
sim_params = SumoParams(render=True)
initial_config = InitialConfig()
vehicles = VehicleParams()
vehicles.add('human', num_vehicles=100)

# %% [markdown]
# We are finally ready to test our network in simulation. In order to do so, we create an `Experiment` object and run the simulation for a number of steps. This is done in the cell below.

# %%
flow_params = dict(
    exp_tag='bay_bridge',
    env_name=TestEnv,
    network=Network,
    simulator='traci',
    sim=sim_params,
    env=env_params,
    net=net_params,
    veh=vehicles,
    initial=initial_config,
)

# number of time steps
flow_params['env'].horizon = 1000
exp = Experiment(flow_params)

# run the sumo simulation
_ = exp.run(1)
# Out:
# <class 'flow.networks.base.Network'>
# Warning: The referenced geometry information (ref='2387017057') is not known
# Warning: The referenced geometry information (ref='30366147') is not known
# Warning: The referenced geometry information (ref='2387017072') is not known
# Warning: The referenced geometry information (ref='2387017027') is not known
# Warning: The referenced geometry information (ref='30366151') is not known
# Warning: Discarding way '6318462' because it has only 1 node(s)
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.residential' (first occurrence for edge '6319820').
# Warning: Discarding way '6331289' because it has only 1 node(s)
# Warning: Discarding unknown compound 'usage.main' in type 'railway.rail|usage.main' (first occurrence for edge '6337419').
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway
# Warning: Converting invalid rail_crossing to priority junction '1582859734'.
# Warning: Converting invalid rail_crossing to priority junction '1582859735'.
# Warning: Converting invalid rail_crossing to priority junction '1723633924'.
# Warning: Converting invalid rail_crossing to priority junction '1723634009'.
# Warning: Could not set connection from '393789575#2_1' to '393789549_4'.
# Warning: Could not set connection from '393789575#2_2' to '393789549_5'.
# Warning: Lane '88559691#0_0' is not connected from any incoming edge at junction '65317030'.
# Warning: Minor green from edge '512984873' to edge '224199013#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# Warning: The traffic light '2071244852' does not control any links; it will not be build.
# Warning: Could not build program '0' for traffic light '2071244852'
# Warning: Minor green from edge '-255330037#0' to edge '255330057#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# Warning: Minor green from edge '-30831808#0' to edge '88463827#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# Warning: Minor green from edge '-328489358#1' to edge '24600262' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# Warning: Minor green from edge '-202485358' to edge '202485370' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# Warning: The traffic light '4563126169' does not control any links; it will not be build.
# Warning: Could not build program '0' for traffic light '4563126169'
# Warning: Speed of straight connection '255330062_0->28353118#0_0' reduced by 8.25 due to turning radius of 12.96 (length=5.68, angle=41.74).
# Warning: Speed of straight connection '-6374818#0_0->107414306#0_0' reduced by 13.04 due to turning radius of 15.33 (length=1.89, angle=22.46).
# Warning: Speed of straight connection '-6374818#1_0->-6374818#0_0' reduced by 13.75 due to turning radius of 13.03 (length=6.10, angle=43.58).
# Warning: Speed of straight connection '6374818#0_0->6374818#1_0' reduced by 14.95 due to turning radius of 9.60 (length=4.39, angle=43.58).
# Warning: Speed of straight connection '107414305#1_0->107414306#1_0' reduced by 12.89 due to turning radius of 15.83 (length=5.22, angle=34.88).
# Warning: 15 total messages of type: Cannot revise pt stop localization for pt line '%', which has no route edges. Ignoring!
# Warning: 74 total messages of type: Converting invalid rail_crossing to priority junction '%'.
# Warning: 19 total messages of type: Could not find corresponding edge or compatible lane for free-floating pt stop '%' (%). Thus, it will be removed!
# Warning: 14 total messages of type: Discarding unknown compound '%' in type '%' (first occurrence for edge '%').
# Warning: 19 total messages of type: Discarding unusable type '%' (first occurrence for edge '%').
# Warning: 76 total messages of type: Discarding way '%' because it has only % node(s)
# Warning: 6 total messages of type: Ignoring restriction relation '%' with unknown to-way.
# Warning: 10 total messages of type: Ignoring restriction relation '%' with unknown via.
# Warning: 26 total messages of type: Ignoring restriction relation '%'.
# Warning: 94 total messages of type: Minor green from edge '%' to edge '%' exceeds %m/s. Maybe a left-turn lane is missing.
# Warning: 10 total messages of type: No node found for reference '%' in relation '%'.
# Warning: 8 total messages of type: No way found for reference '%' in relation '%'
# Warning: 123 total messages of type: PT line in relation % with no stops ignored. Probably OSM file is incomplete.
# Warning: 7 total messages of type: Removed a road without junctions: %.
# Warning: 35 total messages of type: Removed invalid stop '%' from line '%'.
# Warning: 22 total messages of type: Removing pt stop '%' on non existing edge '%'.
# Warning: 17 total messages of type: Shape for junction '%' has distance % to its given position.
# Warning: 60 total messages of type: Speed of % connection '%' reduced by % due to turning radius of % (length=%, angle=%).
# Warning: 4300 total messages of type: The referenced geometry information (ref='%') is not known
# Warning: 12 total messages of type: direction of restriction relation could not be determined%
# Warning: 9 total messages of type: from-edge '%' of restriction relation could not be determined
# Success.
# No routes specified, defaulting to single edge routes.
# Warning: The referenced geometry information (ref='2387017057') is not known
# Warning: The referenced geometry information (ref='30366147') is not known
# Warning: The referenced geometry information (ref='2387017072') is not known
# Warning: The referenced geometry information (ref='2387017027') is not known
# Warning: The referenced geometry information (ref='30366151') is not known
# Warning: Discarding way '6318462' because it has only 1 node(s)
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.residential' (first occurrence for edge '6319820').
# Warning: Discarding way '6331289' because it has only 1 node(s)
# Warning: Discarding unknown compound 'usage.main' in type 'railway.rail|usage.main' (first occurrence for edge '6337419').
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.tertiary' (first occurrence for edge '6347708').
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.secondary' (first occurrence for edge '6347722').
# Warning: Discarding unknown compound 'cycleway.lane' in type 'cycleway.lane|highway.primary' (first occurrence for edge '8916922').
# Warning: Discarding way '8916936' because it has only 1 node(s)
# Warning: Discarding way '8917501' because it has only 1 node(s)
# Warning: Discarding way '8918381' because it has only 1 node(s)
# Warning: Discarding unusable type 'highway.construction' (first occurrence for edge '11415202').
# Warning: Discarding unusable type 'waterway.stream' (first occurrence for edge '24222038').
# Warning: Discarding unusable type 'railway.station' (first occurrence for edge '28714777').
# Warning: Discarding unusable type 'route.ferry' (first occurrence for edge '31772645').
# Warning: Discarding unusable type 'railway.disused|service.spur' (first occurrence for edge '35564586').
# Warning: Removing pt stop '1723739389' on non existing edge '51052112'.
# Warning: Removing pt stop '2504237931' on non existing edge '202485379'.
# Warning: Removing pt stop '2504237933' on non existing edge '202485378#1'.
# Warning: Removing pt stop '257074837' on non existing edge '370555328'.
# Warning: Removing pt stop '3102328775' on non existing edge '305585433#0'.
# Warning: PT line in relation 63223 with no stops ignored. Probably OSM file is incomplete.
# Warning: PT line in relation 63250 with no stops ignored. Probably OSM file is incomplete.
# Warning: PT line in relation 63572 with no stops ignored. Probably OSM file is incomplete.
# Warning: PT line in relation 91022 with no stops ignored. Probably OSM file is incomplete.
# Warning: No way found for reference '669579734' in relation '545923'
# Warning: No way found for reference '667520471' in relation '545923'
# Warning: PT line in relation 905830 with no stops ignored. Probably OSM file is incomplete.
# Warning: direction of restriction relation could not be determined
# Warning: Ignoring restriction relation '1309489'.
# Warning: from-edge '88559669' of restriction relation could not be determined
# Warning: Ignoring restriction relation '1310018'.
# Warning: Ignoring restriction relation '1310019' with unknown type.
# Warning: No node found for reference '65329980' in relation '1310161'.
# Warning: Ignoring restriction relation '1310161' with unknown via.
# Warning: Ignoring restriction relation '1421316' with unknown type.
# Warning: from-edge '324914568' of restriction relation could not be determined
# Warning: Cannot revise pt stop localization for pt line '2851509', which has no route edges. Ignoring!
# Warning: Removed 11 pt stops because they could not be assigned to the network
# Warning: Found sharp turn with radius 8.35 at the end of edge '-215819141#1'.
# Warning: Found sharp turn with radius 8.35 at the start of edge '215819141#1'.
# Warning: Found sharp turn with radius 5.60 at the start of edge '26769842#1'.
# Warning: Found angle of 176.72 degrees at edge '393789561#1', segment 0.
# Warning: Found sharp turn with radius 0.25 at the start of edge '393789561#1'.
# Warning: Found angle of 103.15 degrees at edge '91011801#0', segment 1.
# Warning: Found angle of 104.08 degrees at edge '91011801#0', segment 2.
# Warning: Shape for junction '1463057948' has distance 58.81 to its given position.
# Warning: Shape for junction '2443845209' has distance 21.39 to its given position.
# Warning: Shape for junction '2456072726' has distance 48.50 to its given position.
# Warning: Shape for junction '290110820' has distance 23.46 to its given position.
# Warning: Shape for junction '30362160' has distance 44.97 to its given position.
# Warning: Converting invalid rail_crossing to priority junction '1369473144'.
# Warning: Converting invalid rail_crossing to priority junction '1582859734'.
# Warning: Converting invalid rail_crossing to priority junction '1582859735'.
# Warning: Converting invalid rail_crossing to priority junction '1723633924'.
# Warning: Converting invalid rail_crossing to priority junction '1723634009'.
# Warning: Could not set connection from '393789575#2_1' to '393789549_4'.
# Warning: Could not set connection from '393789575#2_2' to '393789549_5'.
# Warning: Lane '88559691#0_0' is not connected from any incoming edge at junction '65317030'.
# Warning: Minor green from edge '512984873' to edge '224199013#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# Warning: The traffic light '2071244852' does not control any links; it will not be build.
# Warning: Could not build program '0' for traffic light '2071244852'
# Warning: Minor green from edge '-255330037#0' to edge '255330057#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# Warning: Minor green from edge '-30831808#0' to edge '88463827#0' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# Warning: Minor green from edge '-328489358#1' to edge '24600262' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# Warning: Minor green from edge '-202485358' to edge '202485370' exceeds 19.44m/s. Maybe a left-turn lane is missing.
# Warning: The traffic light '4563126169' does not control any links; it will not be build.
# Warning: Could not build program '0' for traffic light '4563126169'
# Warning: Speed of straight connection '255330062_0->28353118#0_0' reduced by 8.25 due to turning radius of 12.96 (length=5.68, angle=41.74).
# Warning: Speed of straight connection '-6374818#0_0->107414306#0_0' reduced by 13.04 due to turning radius of 15.33 (length=1.89, angle=22.46).
# Warning: Speed of straight connection '-6374818#1_0->-6374818#0_0' reduced by 13.75 due to turning radius of 13.03 (length=6.10, angle=43.58).
# Warning: Speed of straight connection '6374818#0_0->6374818#1_0' reduced by 14.95 due to turning radius of 9.60 (length=4.39, angle=43.58).
# Warning: Speed of straight connection '107414305#1_0->107414306#1_0' reduced by 12.89 due to turning radius of 15.83 (length=5.22, angle=34.88).
# Warning: 15 total messages of type: Cannot revise pt stop localization for pt line '%', which has no route edges. Ignoring!
# Warning: 74 total messages of type: Converting invalid rail_crossing to priority junction '%'.
# Warning: 19 total messages of type: Could not find corresponding edge or compatible lane for free-floating pt stop '%' (%). Thus, it will be removed!
# Warning: 14 total messages of type: Discarding unknown compound '%' in type '%' (first occurrence for edge '%').
# Warning: 19 total messages of type: Discarding unusable type '%' (first occurrence for edge '%').
# Warning: 76 total messages of type: Discarding way '%' because it has only % node(s)
# Warning: 6 total messages of type: Ignoring restriction relation '%' with unknown to-way.
# Warning: 10 total messages of type: Ignoring restriction relation '%' with unknown via.
# Warning: 26 total messages of type: Ignoring restriction relation '%'.
# Warning: 94 total messages of type: Minor green from edge '%' to edge '%' exceeds %m/s. Maybe a left-turn lane is missing.
# Warning: 10 total messages of type: No node found for reference '%' in relation '%'.
# Warning: 8 total messages of type: No way found for reference '%' in relation '%'
# Warning: 123 total messages of type: PT line in relation % with no stops ignored. Probably OSM file is incomplete.
# Warning: 7 total messages of type: Removed a road without junctions: %.
# Warning: 35 total messages of type: Removed invalid stop '%' from line '%'.
# Warning: 22 total messages of type: Removing pt stop '%' on non existing edge '%'.
# Warning: 17 total messages of type: Shape for junction '%' has distance % to its given position.
# Warning: 60 total messages of type: Speed of % connection '%' reduced by % due to turning radius of % (length=%, angle=%).
# Warning: 4300 total messages of type: The referenced geometry information (ref='%') is not known
# Warning: 12 total messages of type: direction of restriction relation could not be determined%
# Warning: 9 total messages of type: from-edge '%' of restriction relation could not be determined
# Success.
# ---------------------------------------------------------------------------
# TraCIException                            Traceback (most recent call last)
# ~/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/flow/envs/base.py in reset(self)
#     505                     pos=pos,
# --> 506                     speed=speed)
#     507             except (FatalTraCIError, TraCIException):
#
# ~/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/flow/core/kernel/vehicle/traci.py in add(self, veh_id, type_id, edge, pos, lane, speed)
#    1122             departPos=str(pos),
# -> 1123             departSpeed=str(speed))
#    1124
#
# ~/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/_vehicle.py in add(self, vehID, routeID, typeID, depart, departLane, departPos, departSpeed, arrivalLane, arrivalPos, arrivalSpeed, fromTaz, toTaz, line, personCapacity, personNumber)
#    1426         self._connection._string += messageString
# -> 1427         self._connection._sendExact()
#    1428
#
# ~/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/connection.py in _sendExact(self)
#     105                 self._queue = []
# --> 106                 raise TraCIException(err, prefix[1], _RESULTS[prefix[2]])
#     107             elif prefix[1] != command:
#
# TraCIException: Invalid departlane definition for vehicle 'human_26'.
#
# During handling of the above exception, another exception occurred:
#
# TraCIException                            Traceback (most recent call last)
# /tmp/ipykernel_65007/1959285633.py in <module>
#      16
#      17 # run the sumo simulation
# ---> 18 _ = exp.run(1)
#
# ~/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/flow/core/experiment.py in run(self, num_runs, rl_actions, convert_to_csv)
#     140             vel = []
#     141             custom_vals = {key: [] for key in self.custom_callables.keys()}
# --> 142             state = self.env.reset()
#     143             for j in range(num_steps):
#     144                 t0 = time.time()
#
# ~/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/flow/envs/base.py in reset(self)
#     510                 self.k.vehicle.remove(veh_id)
#     511                 if self.simulator == 'traci':
# --> 512                     self.k.kernel_api.vehicle.remove(veh_id)  # FIXME: hack
#     513                 self.k.vehicle.add(
#     514                     veh_id=veh_id,
#
# ~/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/_vehicle.py in remove(self, vehID, reason)
#    1433            Reasons are defined in module constants and start with REMOVE_'''
#    1434         self._connection._sendByteCmd(
# -> 1435             tc.CMD_SET_VEHICLE_VARIABLE, tc.REMOVE, vehID, reason)
#    1436
#    1437     def moveToXY(self, vehID, edgeID, lane, x, y, angle=tc.INVALID_DOUBLE_VALUE, keepRoute=1):
#
# ~/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/connection.py in _sendByteCmd(self, cmdID, varID, objID, value)
#     141         self._beginMessage(cmdID, varID, objID, 1 + 1)
#     142         self._string += struct.pack("!BB", tc.TYPE_BYTE, value)
# --> 143         self._sendExact()
#     144
#     145     def _sendUByteCmd(self, cmdID, varID, objID, value):
#
# ~/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/connection.py in _sendExact(self)
#     104                 self._string = bytes()
#     105                 self._queue = []
# --> 106                 raise TraCIException(err, prefix[1], _RESULTS[prefix[2]])
#     107             elif prefix[1] != command:
#     108                 raise FatalTraCIError("Received answer %s for command %s." % (prefix[1],
#
# TraCIException: Vehicle 'human_26' is not known

# %% [markdown]
# ## 2. Customizing the Network
#
# While the above example does allow you to view the network within Flow, the simulation is limited for two reasons. For one, vehicles are placed on all edges within the network; if we wished to simulate traffic solely on the on the bridge and do not care about the artireols, for instance, this would result in unnecessary computational burdens. Next, as you may have noticed if you ran the above example to completion, routes in the base network class are defaulted to consist of the vehicles' current edges only, meaning that vehicles exit the network as soon as they reach the end of the edge they are originated on. In the next subsections, we discuss how the network can be modified to resolve these issues.
#
# ### 2.1 Specifying Traversable Edges
#
# In order to limit the edges vehicles are placed on to the road sections edges corresponding to the westbound Bay Bridge, we define an `EDGES_DISTRIBUTION` variable. This variable specifies the names of the edges within the network that vehicles are permitted to originated in, and is assigned to the network via the `edges_distribution` component of the `InitialConfig` input parameter, as seen in the code snippet below. Note that the names of the edges can be identified from the .osm file or by right clicking on specific edges from the SUMO gui (see the figure below).
#
# <img src="img/osm_edge_name.png" width=600>
# <center> **Figure 2**: Name of an edge from SUMO </center>

# %%
# we define an EDGES_DISTRIBUTION variable with the edges within 
# the westbound Bay Bridge 
EDGES_DISTRIBUTION = [
    "11197898",
    "123741311", 
    "123741303",
    "90077193#0",
    "90077193#1", 
    "340686922", 
    "236348366", 
    "340686911#0",
    "340686911#1",
    "340686911#2",
    "340686911#3",
    "236348361", 
    "236348360#0", 
    "236348360#1"
]

# the above variable is added to initial_config
new_initial_config = InitialConfig(
    edges_distribution=EDGES_DISTRIBUTION
)

# %% [markdown]
# ### 2.2 Creating Custom Routes
#
# Next, we choose to specify the routes of vehicles so that they can traverse the entire Bay Bridge, instead of the only the edge they are currently on. In order to this, we create a new network class that inherits all its properties from `Network` and simply redefine the routes by modifying the `specify_routes` variable. This method was originally introduced in Tutorial 07: Creating Custom Network. The new network class looks as follows:

# %%
# we create a new network class to specify the expected routes
class BayBridgeOSMNetwork(Network):

    def specify_routes(self, net_params):
        return {
            "11197898": [
                "11197898", "123741311", "123741303", "90077193#0", "90077193#1", 
                "340686922", "236348366", "340686911#0", "340686911#1",
                "340686911#2", "340686911#3", "236348361", "236348360#0", "236348360#1",
            ],
            "123741311": [
                "123741311", "123741303", "90077193#0", "90077193#1", "340686922", 
                "236348366", "340686911#0", "340686911#1", "340686911#2",
                "340686911#3", "236348361", "236348360#0", "236348360#1"
            ],
            "123741303": [
                "123741303", "90077193#0", "90077193#1", "340686922", "236348366",
                "340686911#0", "340686911#1", "340686911#2", "340686911#3", "236348361",
                "236348360#0", "236348360#1"
            ],
            "90077193#0": [
                "90077193#0", "90077193#1", "340686922", "236348366", "340686911#0",
                "340686911#1", "340686911#2", "340686911#3", "236348361", "236348360#0",
                "236348360#1"
            ],
            "90077193#1": [
                "90077193#1", "340686922", "236348366", "340686911#0", "340686911#1",
                "340686911#2", "340686911#3", "236348361", "236348360#0", "236348360#1"
            ],
            "340686922": [
                "340686922", "236348366", "340686911#0", "340686911#1", "340686911#2",
                "340686911#3", "236348361", "236348360#0", "236348360#1"
            ],
            "236348366": [
                "236348366", "340686911#0", "340686911#1", "340686911#2", "340686911#3",
                "236348361", "236348360#0", "236348360#1"
            ],
            "340686911#0": [
                "340686911#0", "340686911#1", "340686911#2", "340686911#3", "236348361",
                "236348360#0", "236348360#1"
            ],
            "340686911#1": [
                "340686911#1", "340686911#2", "340686911#3", "236348361", "236348360#0",
                "236348360#1"
            ],
            "340686911#2": [
                "340686911#2", "340686911#3", "236348361", "236348360#0", "236348360#1"
            ],
            "340686911#3": [
                "340686911#3", "236348361", "236348360#0", "236348360#1"
            ],
            "236348361": [
                "236348361", "236348360#0", "236348360#1"
            ],
            "236348360#0": [
                "236348360#0", "236348360#1"
            ],
            "236348360#1": [
                "236348360#1"
            ]
        }

# %% [markdown]
# ### 2.3 Rerunning the Simulation
#
# We are now ready to rerun the simulation with fully defined vehicle routes and a limited number of traversable edges. If we run the cell below, we can see the new simulation in action.

# %%
flow_params = dict(
    exp_tag='bay_bridge',
    env_name=TestEnv,
    network=BayBridgeOSMNetwork,
    simulator='traci',
    sim=sim_params,
    env=env_params,
    net=net_params,
    veh=vehicles,
    initial=new_initial_config,
)

# number of time steps
flow_params['env'].horizon = 10000
exp = Experiment(flow_params)

# run the sumo simulation
_ = exp.run(1)

# %% [markdown]
# ## 3. Other Tips
#
# This tutorial introduces how to incorporate OpenStreetMap files in Flow. This feature, however, does not negate other features that are introduced in other tutorials and documentation. For example, if you would like to not have vehicles be originated side-by-side within a network, this can still be done by specifying a "random" spacing for vehicles as follows:
#
#     initial_config = InitialConfig(
#         spacing="random",
#         edges_distribution=EDGES_DISTRIBUTION
#     )
#
# In addition, inflows of vehicles can be added to networks imported from OpenStreetMap as they are for any other network (see the tutorial on adding inflows for more on this).
