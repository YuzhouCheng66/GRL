# %%
from flow.core.params import VehicleParams, InFlows, SumoCarFollowingParams, SumoParams, EnvParams, InitialConfig, \
    NetParams, SumoLaneChangeParams, TrafficLightParams
from flow.controllers import IDMController, RLController
from controller import SpecificMergeRouter, NearestMergeRouter
from network import HighwayRampsNetwork, ADDITIONAL_NET_PARAMS
import sys



# ----------- Configurations -----------#
TRAINING = True
# TRAINING = False

# TESTING = True
TESTING = True

# DEBUG = True
DEBUG = False

RENDER = True
# RENDER = True

NEAREST_MERGE = False
# NEAREST_MERGE = True

NUM_HUMAN = 20
actual_num_human = 20

NUM_MERGE_0 = 10
NUM_MERGE_1 = 10

MAX_AV_SPEED = 14
MAX_HV_SPEED = 10

VEH_COLORS = ['red', 'red'] if NEAREST_MERGE else ['red', 'green']

#######################################################


Router = NearestMergeRouter if NEAREST_MERGE else SpecificMergeRouter

vehicles = VehicleParams()
vehicles.add(veh_id="human",
             lane_change_params=SumoLaneChangeParams('only_strategic_safe'),
             car_following_params=SumoCarFollowingParams(speed_mode='right_of_way', min_gap=5, tau=1,
                                                         max_speed=MAX_HV_SPEED),
             acceleration_controller=(IDMController, {}),
             routing_controller=(Router, {}),
             )

vehicles.add(veh_id="merge_0",
             lane_change_params=SumoLaneChangeParams('no_cooperative_safe'),
             car_following_params=SumoCarFollowingParams(speed_mode='no_collide', min_gap=1, tau=1,
                                                         max_speed=MAX_AV_SPEED),
             acceleration_controller=(RLController, {}),
             routing_controller=(Router, {}),
             color=VEH_COLORS[0])

vehicles.add(veh_id="merge_1",
             lane_change_params=SumoLaneChangeParams('no_cooperative_safe'),
             car_following_params=SumoCarFollowingParams(speed_mode='no_collide', min_gap=1, tau=1,
                                                         max_speed=MAX_AV_SPEED),
             acceleration_controller=(RLController, {}),
             routing_controller=(Router, {}),
             color=VEH_COLORS[1])

initial_config = InitialConfig(spacing='uniform')

inflow = InFlows()
inflow.add(veh_type="human",
           edge="highway_0",
           probability=0.2,
           depart_lane='random',
           depart_speed='random',
           route='routehighway_0_0',
           number=actual_num_human-1)

#--------------------------------------------------------------------------
new = {"departPos": 100}

inflow.add(veh_type="human",
           edge="highway_0",
           probability=1,
           depart_lane='random',
           depart_speed='random',
           route='routehighway_0_0',
           number=1,
           **new)
#--------------------------------------------------------------------------

inflow.add(veh_type="merge_0",
           edge="highway_0",
           probability=0.1,
           depart_lane='random',
           depart_speed='random',
           route='routehighway_0_0',
           number=NUM_MERGE_0)

inflow.add(veh_type="merge_1",
           edge="highway_0",
           probability=0.1,
           depart_lane='random',
           depart_speed='random',
           route='routehighway_0_0',
           number=NUM_MERGE_1)

sim_params = SumoParams(sim_step=0.1, restart_instance=True, render=RENDER)

from specific_environment import MergeEnv

intention_dic = {"human": 0, "merge_0": 1, "merge_1": 1} if NEAREST_MERGE else {"human": 0, "merge_0": 1, "merge_1": 2}
terminal_edges = ['off_ramp_0', 'off_ramp_1', 'highway_2']

env_params = EnvParams(warmup_steps=100,
                       additional_params={"intention": intention_dic,
                                          "max_av_speed": MAX_AV_SPEED,
                                          "max_hv_speed": MAX_HV_SPEED})

additional_net_params = ADDITIONAL_NET_PARAMS.copy()
additional_net_params['num_vehicles'] = NUM_HUMAN + NUM_MERGE_0 + NUM_MERGE_1
additional_net_params['num_cav'] = NUM_MERGE_0 + NUM_MERGE_1
additional_net_params['num_hv'] = NUM_HUMAN
additional_net_params['terminal_edges'] = terminal_edges

net_params = NetParams(inflows=inflow, additional_params=additional_net_params)

traffic_lights = TrafficLightParams()

network = HighwayRampsNetwork("highway_ramp", vehicles, net_params, initial_config, traffic_lights)


# ----------- Model Building -----------#
flow_params = dict(
    exp_tag='test_network',
    env_name=MergeEnv,
    network=network,
    simulator='traci',
    sim=sim_params,
    env=env_params,
    net=net_params,
    veh=vehicles,
    initial=initial_config,
    tls=traffic_lights
)

# number of time steps
flow_params['env'].horizon = 2500


from Experiment.DQN_experiments import Experiment

exp = Experiment(flow_params)

# run the sumo simulation
exp.run(num_runs=1, train ing=TRAINING,
        testing=TESTING,
        num_human=NUM_HUMAN,
        actual_num_human=actual_num_human,
        num_cav=(NUM_MERGE_0 + NUM_MERGE_1),
        model='GRL',
        debug=DEBUG)
# Out:
# satisfied:  flow_2.3
# satisfied:  flow_3.4
# satisfied:  flow_2.5
# satisfied:  flow_3.5
# Counter({'num_full_filled': 4})
# done in:  1459
# Training Episode: 1 Reward: -261.95428351877496
# Statistics: [('average_q', nan), ('average_loss', nan), ('cumulative_steps', 1359), ('n_updates', 0), ('rlen', 1359)]
# Error during start: Traceback (most recent call last):
#   File "/home/yzcheng/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/flow/core/kernel/simulation/traci.py", line 255, in start_simulation
#     traci_connection.setOrder(0)
#   File "/home/yzcheng/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/connection.py", line 348, in setOrder
#     self._sendExact()
#   File "/home/yzcheng/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/connection.py", line 99, in _sendExact
#     raise FatalTraCIError("connection closed by SUMO")
# traci.exceptions.FatalTraCIError: connection closed by SUMO
#
# Error during teardown: [Errno 3] No such process
# FATAL: exception not rethrown
#  Retrying in 1 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 2 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 3 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 4 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 5 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 6 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 7 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 8 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 9 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 10 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 11 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 12 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 13 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 14 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 15 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 16 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 17 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 18 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 19 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 20 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 21 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 22 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 23 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 24 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 25 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 26 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 27 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 28 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 29 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 30 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 31 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 32 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 33 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 34 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 35 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 36 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 37 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 38 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 39 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 40 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 41 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 42 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 43 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 44 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 45 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 46 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 47 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 48 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 49 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 50 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 51 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 52 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 53 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 54 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 55 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 56 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 57 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 58 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 59 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 60 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 61 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 62 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 63 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 64 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 65 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 66 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 67 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 68 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 69 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 70 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 71 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 72 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 73 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 74 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 75 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 76 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 77 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 78 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 79 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 80 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 81 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 82 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 83 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 84 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 85 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 86 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 87 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 88 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 89 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 90 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 91 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 92 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 93 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 94 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 95 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 96 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 97 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 98 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 99 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
#  Retrying in 100 seconds
# Could not connect to TraCI server at localhost:50665 [Errno 111] Connection refused
# Error during start: Traceback (most recent call last):
#   File "/home/yzcheng/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/flow/core/kernel/simulation/traci.py", line 254, in start_simulation
#     traci_connection = traci.connect(port, numRetries=100)
#   File "/home/yzcheng/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/__init__.py", line 75, in connect
#     raise FatalTraCIError("Could not connect in %s tries" % (numRetries + 1))
# traci.exceptions.FatalTraCIError: Could not connect in 101 tries
#
# Error during teardown: [Errno 3] No such process
# Error during start: Traceback (most recent call last):
#   File "/home/yzcheng/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/flow/core/kernel/simulation/traci.py", line 255, in start_simulation
#     traci_connection.setOrder(0)
#   File "/home/yzcheng/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/connection.py", line 348, in setOrder
#     self._sendExact()
#   File "/home/yzcheng/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/connection.py", line 99, in _sendExact
#     raise FatalTraCIError("connection closed by SUMO")
# traci.exceptions.FatalTraCIError: connection closed by SUMO
#
# Error during teardown: [Errno 3] No such process
# Error during start: Traceback (most recent call last):
#   File "/home/yzcheng/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/flow/core/kernel/simulation/traci.py", line 255, in start_simulation
#     traci_connection.setOrder(0)
#   File "/home/yzcheng/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/connection.py", line 348, in setOrder
#     self._sendExact()
#   File "/home/yzcheng/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/connection.py", line 99, in _sendExact
#     raise FatalTraCIError("connection closed by SUMO")
# traci.exceptions.FatalTraCIError: connection closed by SUMO
#
# Error during teardown: [Errno 3] No such process
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12311/399189206.py in <module>
#     157         num_cav=(NUM_MERGE_0 + NUM_MERGE_1),
#     158         model='GRL',
# --> 159         debug=DEBUG)
#
# ~/maai/TorchGRL/GRL_Simulation/Experiment/DQN_experiments.py in run(self, num_runs, training, testing, num_human, actual_num_human, num_cav, model, debug, num_merge_0, num_merge_1)
#     165         debug_training = False
#     166         if training:
# --> 167             Training_GRLModels(GRL, GRL_Dqn, self.env, n_episodes, max_episode_len, save_dir, warmup, debug_training)
#     168
#     169         # 进行模型测试
#
# ~/maai/TorchGRL/GRL_utils/Train_and_Test.py in Training_GRLModels(GRL_Net, GRL_model, env, n_episodes, max_episode_len, save_dir, warmup, debug)
#      36                 print("param:", parameters)
#      37             print("------------------------------------")
# ---> 38         obs = env.reset()
#      39         R = 0  # 行为奖励
#      40         t = 0  # 时间步长
#
# ~/maai/TorchGRL/GRL_Simulation/environment.py in reset(self)
#     471             self.k.vehicle.master_kernel = self.k
#     472             # restart the sumo instance
# --> 473             self.restart_simulation(self.sim_params)
#     474
#     475         # perform shuffling (if requested)
#
# ~/maai/TorchGRL/GRL_Simulation/environment.py in restart_simulation(self, sim_params, render)
#     272         self.k.vehicle.initialize(deepcopy(self.network.vehicles))
#     273         kernel_api = self.k.simulation.start_simulation(
# --> 274             network=self.k.network, sim_params=self.sim_params)
#     275         self.k.pass_api(kernel_api)
#     276
#
# ~/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/flow/core/kernel/simulation/traci.py in start_simulation(self, network, sim_params)
#     253
#     254                 traci_connection = traci.connect(port, numRetries=100)
# --> 255                 traci_connection.setOrder(0)
#     256                 traci_connection.simulationStep()
#     257
#
# ~/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/connection.py in setOrder(self, order)
#     346         self._queue.append(tc.CMD_SETORDER)
#     347         self._string += struct.pack("!BBi", 1 + 1 + 4, tc.CMD_SETORDER, order)
# --> 348         self._sendExact()
#     349
#     350     def close(self, wait=True):
#
# ~/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/connection.py in _sendExact(self)
#      93             length = struct.pack("!i", len(self._string) + 4)
#      94             self._socket.send(length + self._string)
# ---> 95             result = self._recvExact()
#      96         if not result:
#      97             self._socket.close()
#
# ~/anaconda3/envs/TorchGRL/lib/python3.7/site-packages/traci/connection.py in _recvExact(self)
#      72             result = bytes()
#      73             while len(result) < 4:
# ---> 74                 t = self._socket.recv(4 - len(result))
#      75                 if not t:
#      76                     return None
#
# KeyboardInterrupt:
